# %% [markdown]
# #Print Statement

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %% [markdown]
# #Buyinput

# %%
name=input("Enter the institute name? :")
# Out:
# Enter the institute name? : HOPE AI

# %% [markdown]
# #BuyInputs

# %%
name=input("Enter the name :")
# Out:
# Enter the name : Raj

# %%
age=input("Enter the age :")
# Out:
# Enter the age : 15

# %%
school=input("Enter the school name :")
# Out:
# Enter the school name : Guru school

# %%
degree=input("Enter the drgree :")
# Out:
# Enter the drgree : B.E CSE

# %% [markdown]
# #Addition

# %%
a=43
b=34
add=a+b
print(add)
# Out:
# 77

# %% [markdown]
# #Subtraction

# %%
a=43
b=34
sub=a-b
print(sub)
# Out:
# 9

# %% [markdown]
# #Multiplication

# %%
a=63
b=97
Mul=a*b
print(Mul)
# Out:
# 6111

# %% [markdown]
# #Division

# %%
a=76
b=31
Float Div=a/b
print(Float Div)
# Out:
#   Cell In[10], line 3
#     Float Div=a/b
#           ^
# SyntaxError: invalid syntax

# %%
a=76
b=31
Float Div = a / b
print(Float Div)
# Out:
#   Cell In[11], line 3
#     Float Div = a / b
#           ^
# SyntaxError: invalid syntax

# %%
a=76
b=31
Float_Div=a/b
print(Float_Div)
# Out:
# 2.4516129032258065

# %% [markdown]
# #Floor division

# %%
a=76
b=31
Floor_Div=a/b
print(Floor_Div)
# Out:
# 2.4516129032258065

# %%
a=76
b=31
Floor_Div=a//b
print(Floor_Div)
# Out:
# 2

# %% [markdown]
# #Modulo

# %%
a=76
b=31
Modulo=a%b
print(Modulo)
# Out:
# 14

# %% [markdown]
# #Power

# %%
a=4
b=4
Power=a**b
print(Power)
# Out:
# 256
