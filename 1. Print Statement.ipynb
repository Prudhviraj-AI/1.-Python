# %%
print()

# %%
print("Welcome to the Hope AI")
# Out:
# Welcome to the Hope AI

# %%
print("Prudhviraj")
# Out:
# Prudhviraj

# %%
Print("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Print("hello")
#
# NameError: name 'Print' is not defined

# %%
#Error - Print is not defined (Name Error)
#Syntax Error - Print word should be in lower case

# %%
print("hello")
# Out:
# hello
