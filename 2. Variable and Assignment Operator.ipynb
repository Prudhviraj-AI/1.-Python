# %%
num1=10
num2=30
add=num1+num2

# %%
num1=10
num2=30
add=num1+num2
print("add")
# Out:
# add

# %%
num1=10
num2=30
add=num1+num2
print(add)
# Out:
# 40

# %%
#Another example for addition

# %%
Num1=25
Num2=45
Sub=Num1-Num2
print(sub)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 Num2=45
#       3 Sub=Num1-Num2
# ----> 4 print(sub)
#
# NameError: name 'sub' is not defined

# %%
Num1=25
Num2=45
Sub=Num1-Num2
print(Sub)
# Out:
# -20

# %%
Num1=12
Num2=12
Mul=Num1*Num2
print(Mul)
# Out:
# 144

# %%
#Input Statement (collecting from end user)

# %%
num1=input("Enter the num1:")
# Out:
# Enter the num1: 35

# %%
num2=input("Enter the num2:")
# Out:
# Enter the num2: 65

# %%
add=num1+num2

# %%
print(add)
# Out:
# 3565

# %%
num1=input("Enter the num1:")
# Out:
#   Cell In[17], line 1
#     num1=input("Enter the num1:"))
#                                  ^
# SyntaxError: unmatched ')'

# %%
#Adding Integer before Input

# %%
num1=int(input("Enter the num1:"))
# Out:
# Enter the num1: 35

# %%
num2=int(input("Enter the num2:"))
# Out:
# Enter the num2: 65

# %%
add=num1+num2
print(add)
# Out:
# 100

# %%
#Name error
#spelling mistake
#variabe not defined

# %%
num1=int(input("Enter the num1:"))
# Out:
# Enter the num1: 25

# %%
num2=int(input("Enter the num2:")
# Out:
#   Cell In[33], line 1
#     num2=int(input("Enter the num2:")
#                                      ^
# SyntaxError: incomplete input

# %%
#Incomplete input - bracket not close properly
