# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# Corrected code --> Missing colon : after range(5)
for i in range(5):
    print(i)

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# Corrected code --> Cannot add int and str directly
a = 10
b = "5"
print(a + int(b))

Output: 15
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# Corrected code --> Missing colon : after function definition
def add_numbers(a, b):
    return a + b

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# Corrected code --> Index out of range (valid indices: 0–3)
numbers = [1, 2, 3, 4]
print(numbers[3])

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# Corrected code --> Missing parentheses
print("Hello, World!")

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# Corrected code --> ZeroDivisionError, Changed denominator to 1 to avoid division by zero
x = 5 / 1

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# Corrected code --> Cannot link str and int
name = "Alice"
age = 25
print("Name: " + name + ", Age: " + str(age))

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# Corrected code --> Negative step but start < stop (loop never runs)
for i in range(1, 10):
    print(i)

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# Corrected code --> Used assignment operator = instead of comparison operator ==
x = 10
if x == 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# Corrected code --> Missing colon : after function definition
def greet(name):
    print("Hello, " + name)
